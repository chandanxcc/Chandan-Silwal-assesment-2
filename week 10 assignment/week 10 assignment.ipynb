# %% [markdown]
# # New Section

# %% [markdown]
# **1.1 Problem 1: Tip Calculator**
#
# 1.1.1 The Scenario
# You work at a Perth restaurant. The manager wants a simple tool where staff can enter:
#
# The bill amount (e.g., $45.80)
# The tip percentage (e.g., 15%)
# And get back:
#
# The tip amount
# The total amount to charge
# 1.1.2 What You Must Submit
# STEP 1: Understand the Problem
#
# In your own words, what is this program supposed to do? (2-3 sentences)
#
# **This program is designed to act as a digital calculator for restaurant staff to quickly determine the gratuity and final cost of a meal. By inputting the raw bill amount and a specific tip percentage, the tool automates the math to provide the exact dollar value of the tip and the total amount to be charged to the customer.**

# %% [markdown]
# **STEP 2: Identify Inputs and Outputs**
#
# **INPUTS:**
#
# > * **Bill Amount:** The user provides the cost of the meal. This is **numerical data** (Float/Decimal).
# > * **Tip Percentage:** The user provides the percentage they wish to tip. This is **numerical data** (Integer or Float).
# >
# >
#
# **OUTPUTS:**
#
# > * **Tip Amount:** The program shows the dollar value of the tip. This is in **currency format** (e.g., $6.87).
# > * **Total Amount:** The program shows the bill plus the tip. This
#  is
#   in
#    currency
#     format  (e.g., $52.67).
# >
# >
#
# ---
#
# **STEP 3: Work It By Hand**
#
# **Bill amount:** $45.80
#
# **Tip percentage:** 15%
#
# **Write the steps:**
#
# > 1. **First calculation I would do:** Convert the percentage to a decimal and multiply it by the bill to find the tip ($45.80 \times 0.15 = 6.87$).
# > 2. **Second calculation:** Add the calculated tip to the original bill amount ($45.80 + 6.87 = 52.67$).
# > 3. **Final step:** Round the results to two decimal places to ensure they represent valid Australian currency.
# > 4. **What I would tell the staff member:** The tip amount  is $6.87  and
# total
#  amount
#   is
#     $52.67
# >
# >

# %% [markdown]
# **1.2.2 What You Must Submit**
#
# **STEP 1: Understand the Problem**
# In your own words, what is this program supposed to do? (2-3 sentences)
#
# > This program is designed to calculate the financial penalty for library books that are returned after their due date. It applies a fixed daily rate for every day the book is overdue, while also enforcing a strict price ceiling so that no single fine exceeds a specific maximum limit.
#
# **STEP 2: Identify Inputs and Outputs**
# **INPUTS:**
#
# > * **Days Overdue:** The librarian provides the number of days late. This is **numerical data** (Integer/Whole number).
# >
# >
#
# **OUTPUTS:**
#
# > * **Fine Amount:** The calculated dollar value of the penalty (formatted as currency).
# > * **Status Message:** If the fine hits the limit, the program displays "Maximum fine reached."
# >
# >
#
# **STEP 3: Work It By Hand**
# Show me you understand the logic. Calculate these three cases manually:
#
# **Case A: Book is 5 days late**
#
# > * **My calculation:** 5 days × $0.50 per day = $2.50
# > * **Fine:** $2.50
# >
# >
#
# **Case B: Book is 25 days late**
#
# > * **My calculation:** 25 days × $0.50 per day = $12.50. Since $12.50 is greater than the $10.00 limit, the fine is reduced to the maximum.
# > * **Fine:** $10.00
# > * **Special note:** This is different because the raw mathematical result exceeds the library's maximum fine policy, requiring the program to "cap" the output at $10.00 and notify the user that the limit was reached.
# >
# >
#
# **Case C: Book is 0 days late**
#
# > * **My calculation:** 0 days × $0.50 per day = $0.00
# > * **Fine:** $0.00
# >
# >

# %% [markdown]
# ### 1.2.2 What You Must Submit
#
# **STEP 1: Understand the Problem**
# In your own words, what is this program supposed to do? (2-3 sentences)
#
# > This program is designed to calculate the financial penalty for library books that are returned after their due date. It applies a fixed daily rate for every day the book is overdue, while also enforcing a strict price ceiling so that no single fine exceeds a specific maximum limit.
#
# **STEP 2: Identify Inputs and Outputs**
# **INPUTS:**
#
# > * **Days Overdue:** The librarian provides the number of days late as a whole number (Integer).
# >
# >
#
# **OUTPUTS:**
#
# > * **Fine Amount:** The total dollar fee calculated based on the days overdue (formatted as currency).
# > * **Status Message:** A specific notification if the fine has reached the $10.00 cap, such as “Maximum fine reached.”
# >
# >
#
# **STEP 3: Work It By Hand**
# Show me you understand the logic. Calculate these three cases manually:
#
# **Case A: Book is 5 days late**
#
# > * **My calculation:** $5 \text{ days} \times \$0.50 \text{ per day} = \$2.50$
# > * **Fine:** $2.50
# >
# >
#
# **Case B: Book is 25 days late**
#
# > * **My calculation:** $25 \text{ days} \times \$0.50 \text{ per day} = \$12.50$. Since this is over the maximum limit of $\$10.00$, the fine is set to $\$10.00$.
# > * **Fine:** $10.00
# > * **Special note:** This is different because the raw calculation ($12.50) exceeds the maximum allowed fine. The program must apply a logic "cap" to ensure the librarian only charges the maximum fee of $10.00.
# >
# >
#
# **Case C: Book is 0 days late**
#
# > * **My calculation:** $0 \text{ days} \times \$0.50 \text{ per day} = \$0.00$
# > * **Fine:** $0.00
# >
# >
